# %%
imagedir = "/home/kyra/animl/examples/test_data/Peru/S90/SDZG 1"

# %%
import FileManagement
from SymLinkClasses import sort_and_copy

# %%
images = FileManagement.buildFileManifest(imagedir)

# %%
images
# Out:
#                                              FilePath      FileName  \
# 0   /home/kyra/animl/examples/test_data/Peru/S90/S...  EK000024.JPG
# 1   /home/kyra/animl/examples/test_data/Peru/S90/S...  EK000034.JPG
# 2   /home/kyra/animl/examples/test_data/Peru/S90/S...  EK000045.JPG
# 3   /home/kyra/animl/examples/test_data/Peru/S90/S...  EK000052.JPG
# 4   /home/kyra/animl/examples/test_data/Peru/S90/S...  EK000013.JPG
# 5   /home/kyra/animl/examples/test_data/Peru/S90/S...  EK000035.JPG
# 6   /home/kyra/animl/examples/test_data/Peru/S90/S...  EK000028.JPG
# 7   /home/kyra/animl/examples/test_data/Peru/S90/S...  EK000009.JPG
# 8   /home/kyra/animl/examples/test_data/Peru/S90/S...  EK000047.JPG
# 9   /home/kyra/animl/examples/test_data/Peru/S90/S...  EK000001.JPG
# 10  /home/kyra/animl/examples/test_data/Peru/S90/S...  EK000010.JPG
# 11  /home/kyra/animl/examples/test_data/Peru/S90/S...  EK000030.JPG
# 12  /home/kyra/animl/examples/test_data/Peru/S90/S...  EK000031.JPG
# ...
